# %% [markdown]
# # Regresión Logística con scikit-learn (con Pipelines)
#
# En este cuaderno se demostrará cómo utilizar la regresión logística usando un **pipeline** de scikit-learn. El modelo se entrenará con el conjunto de datos de cáncer de mama disponible en scikit-learn, que es un problema de clasificación binaria.
#
# **Objetivos del notebook**:
#
# 1. Cargar y explorar el conjunto de datos
# 2. Dividir los datos en conjuntos de entrenamiento y prueba
# 3. Crear un pipeline que estandarice las características y entrene un modelo de regresión logística
# 4. Evaluar el modelo usando métricas de clasificación
# 5. Visualizar resultados con una matriz de confusión y curva ROC

# %%
# !pip install matplotlib ipykernel matplotlib-inline
# Out:
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (3.10.6)
# Requirement already satisfied: ipykernel in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (6.30.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (0.1.7)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: appnope>=0.1.2 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipykernel) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipykernel) (9.4.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipykernel) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipykernel) (27.0.2)
# Requirement already satisfied: tornado>=6.2 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.8)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/llm/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)

# %%
# Importar librerías necesarias
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc
import matplotlib
import matplotlib.pyplot as plt

# Configuración para gráficos
matplotlib.use('module://matplotlib_inline.backend_inline')

# %% [markdown]
# ## 1. Cargar y explorar los datos
# Utilizamos el dataset de cáncer de mama. A continuación se muestran las dimensiones y un vistazo a las primeras filas.

# %%
# Cargar el dataset
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target

# Mostrar dimensiones y primeras filas
print("Dimensiones del dataframe:", df.shape)
df.head()
# Out:
# Dimensiones del dataframe: (569, 31)
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 2. Dividir los datos
# Dividimos los datos en conjuntos de entrenamiento y prueba con un tamaño de prueba del 30%. Utilizamos `stratify` para mantener la proporción de clases.

# %%
# Dividir datos
X = df.drop('target', axis=1)
y = df['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

print(f"Tamaño de entrenamiento: {X_train.shape}, Tamaño de prueba: {X_test.shape}")


print(X_train.head())

print(y_train.head())
# Out:
# Tamaño de entrenamiento: (426, 30), Tamaño de prueba: (143, 30)
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 517        19.89         20.26          130.50     1214.0          0.10370
# 287        12.89         13.12           81.89      515.9          0.06955
# 25         17.14         16.40          116.00      912.7          0.11860
# 253        17.30         17.08          113.00      928.2          0.10080
# 369        22.01         21.90          147.20     1482.0          0.10630
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 517           0.13100          0.1411              0.09431         0.1802
# 287           0.03729          0.0226              0.01171         0.1337
# 25            0.22760          0.2229              0.14010         0.3040
# 253           0.10410          0.1266              0.08353         0.1813
# 369           0.19540          0.2448              0.15010         0.1824
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 517                 0.06188  ...         23.73          25.23
# 287                 0.05581  ...         13.62          15.54
# 25                  0.07413  ...         22.25          21.40
# 253                 0.05613  ...         19.85          25.09
# 369                 0.06140  ...         27.66          25.80
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 517            160.5      1646.0           0.14170             0.3309
# 287             87.4       577.0           0.09616             0.1147
# 25             152.4      1461.0           0.15450             0.3949
# 253            130.9      1222.0           0.14160             0.2405
# 369            195.0      2227.0           0.12940             0.3885
#
#      worst concavity  worst concave points  worst symmetry  \
# 517           0.4185               0.16130          0.2549
# 287           0.1186               0.05366          0.2309
# 25            0.3853               0.25500          0.4066
# 253           0.3378               0.18570          0.3138
# 369           0.4756               0.24320          0.2741
#
#      worst fractal dimension
# 517                  0.09136
# 287                  0.06915
# 25                   0.10590
# 253                  0.08113
# 369                  0.08574
#
# [5 rows x 30 columns]
# 517    0
# 287    1
# 25     0
# 253    0
# 369    0
# Name: target, dtype: int64

# %% [markdown]
# ## 3. Crear un Pipeline
#
# El pipeline estandariza las características con `StandardScaler` y luego aplica `LogisticRegression`. Se realiza el ajuste usando los datos de entrenamiento.

# %%
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('logreg', LogisticRegression(max_iter=1000))
])

pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('logreg', LogisticRegression(max_iter=1000))])

# %% [markdown]
# ## 4. Evaluación del modelo
# Se calculan las métricas de evaluación comunes: **accuracy**, **precision**, **recall** y **f1**. También se muestra la matriz de confusión y la curva ROC.

# %%
# Predicciones
y_pred = pipe.predict(X_test)

# Métricas de evaluación
acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)
print("Matriz de confusión:", cm)
# Out:
# Accuracy: 0.9860
# Precision: 0.9889
# Recall: 0.9889
# F1 Score: 0.9889
# Matriz de confusión: [[52  1]
#  [ 1 89]]

# %% [markdown]
# ## 5. Guardar el modelo entrenado
#
# Una vez que el modelo está entrenado y evaluado, es importante guardarlo para poder reutilizarlo posteriormente sin necesidad de volver a entrenarlo.

# %%
import joblib
import os

# Crear directorio para guardar modelos si no existe
model_dir = "modelos"
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# Guardar el pipeline completo (incluye scaler y modelo)
model_path = os.path.join(model_dir, "logistic_regression_pipeline.pkl")
joblib.dump(pipe, model_path)

print(f"Modelo guardado exitosamente en: {model_path}")
print(f"Tamaño del archivo: {os.path.getsize(model_path)} bytes")
# Out:
# Modelo guardado exitosamente en: modelos/logistic_regression_pipeline.pkl
# Tamaño del archivo: 3089 bytes

# %% [markdown]
# ## 6. Cargar el modelo guardado
#
# Ahora simulamos que estamos en una nueva sesión y necesitamos cargar el modelo previamente entrenado para hacer predicciones.

# %%
# Cargar el modelo guardado
model_path = os.path.join("modelos", "logistic_regression_pipeline.pkl")

if os.path.exists(model_path):
    loaded_pipeline = joblib.load(model_path)
    print(f"Modelo cargado exitosamente desde: {model_path}")
    
    print("Componentes del pipeline:")
    for step_name, step_object in loaded_pipeline.steps:
        print(f"  - {step_name}: {type(step_object).__name__}")
else:
    print(f"Error: No se encontró el archivo del modelo en {model_path}")
    print("Asegúrate de ejecutar primero la celda de guardado del modelo")
# Out:
# Modelo cargado exitosamente desde: modelos/logistic_regression_pipeline.pkl
# Componentes del pipeline:
#   - scaler: StandardScaler
#   - logreg: LogisticRegression

# %% [markdown]
# ## 7. Probar el modelo cargado con datos
#
# Vamos a probar el modelo cargado usando los datos de prueba para verificar que funciona correctamente y produce los mismos resultados que el modelo original.

# %%
# Hacer predicciones con el modelo cargado
y_pred_loaded = loaded_pipeline.predict(X_test)
y_pred_proba_loaded = loaded_pipeline.predict_proba(X_test)

# Evaluar el modelo cargado
acc_loaded = accuracy_score(y_test, y_pred_loaded)
prec_loaded = precision_score(y_test, y_pred_loaded)
recall_loaded = recall_score(y_test, y_pred_loaded)
f1_loaded = f1_score(y_test, y_pred_loaded)

print("=== Resultados del modelo cargado ===")
print(f"Accuracy: {acc_loaded:.4f}")
print(f"Precision: {prec_loaded:.4f}")
print(f"Recall: {recall_loaded:.4f}")
print(f"F1 Score: {f1_loaded:.4f}")

# Verificar que las predicciones son idénticas al modelo original
predicciones_identicas = np.array_equal(y_pred, y_pred_loaded)
print(f"\n¿Las predicciones son idénticas al modelo original? {predicciones_identicas}")

# Mostrar algunas predicciones individuales
print("\n=== Ejemplos de predicciones ===")
print("Índice | Real | Predicción | Probabilidad [Maligno, Benigno]")
print("-" * 60)
for i in range(5):
    real = "Benigno" if y_test.iloc[i] == 1 else "Maligno"
    pred = "Benigno" if y_pred_loaded[i] == 1 else "Maligno"
    prob_maligno = y_pred_proba_loaded[i][0]
    prob_benigno = y_pred_proba_loaded[i][1]
    print(f"{i:6d} | {real:6s} | {pred:10s} | [{prob_maligno:.3f}, {prob_benigno:.3f}]")
# Out:
# === Resultados del modelo cargado ===
# Accuracy: 0.9860
# Precision: 0.9889
# Recall: 0.9889
# F1 Score: 0.9889
#
# ¿Las predicciones son idénticas al modelo original? True
#
# === Ejemplos de predicciones ===
# Índice | Real | Predicción | Probabilidad [Maligno, Benigno]
# ------------------------------------------------------------
#      0 | Benigno | Benigno    | [0.031, 0.969]
#      1 | Maligno | Maligno    | [1.000, 0.000]
#      2 | Benigno | Benigno    | [0.441, 0.559]
#      3 | Benigno | Benigno    | [0.061, 0.939]
#      4 | Maligno | Maligno    | [0.825, 0.175]

# %% [markdown]
# ### Prueba con datos nuevos/sintéticos
#
# También podemos probar el modelo con datos completamente nuevos para demostrar cómo usarlo en un escenario real.

# %%
np.random.seed(42)

nuevas_muestras = np.array([
    [12.5, 15.2, 82.1, 490.0, 0.095, 0.08, 0.04, 0.02, 0.18, 0.062,
     0.25, 0.85, 1.8, 18.5, 0.006, 0.015, 0.018, 0.007, 0.014, 0.002,
     13.8, 18.9, 89.2, 580.3, 0.125, 0.152, 0.089, 0.045, 0.265, 0.078],
    
    [18.8, 22.1, 125.4, 1105.0, 0.118, 0.165, 0.145, 0.095, 0.205, 0.068,
     0.85, 2.15, 5.8, 95.2, 0.011, 0.045, 0.055, 0.025, 0.032, 0.006,
     25.2, 30.5, 165.8, 1895.0, 0.155, 0.385, 0.425, 0.185, 0.315, 0.095],
    
    [15.2, 18.5, 99.8, 720.0, 0.105, 0.125, 0.085, 0.055, 0.192, 0.065,
     0.45, 1.25, 3.2, 42.8, 0.008, 0.025, 0.032, 0.015, 0.022, 0.004,
     17.8, 23.2, 115.6, 980.5, 0.138, 0.235, 0.185, 0.095, 0.285, 0.085]
])

feature_names = data.feature_names
nuevas_muestras_df = pd.DataFrame(nuevas_muestras, columns=feature_names)

print("=== Predicciones para muestras nuevas ===")
print("Características de las muestras:")
print(nuevas_muestras_df[['mean radius', 'mean texture', 'mean perimeter', 'mean area']].round(2))

pred_nuevas = loaded_pipeline.predict(nuevas_muestras_df)
prob_nuevas = loaded_pipeline.predict_proba(nuevas_muestras_df)

print("\nResultados de predicción:")
print("Muestra | Predicción | Probabilidad Maligno | Probabilidad Benigno")
print("-" * 65)
for i in range(len(nuevas_muestras)):
    pred_label = "Benigno" if pred_nuevas[i] == 1 else "Maligno"
    prob_maligno = prob_nuevas[i][0]
    prob_benigno = prob_nuevas[i][1]
    print(f"   {i+1:1d}    |   {pred_label:7s}  |       {prob_maligno:.3f}      |       {prob_benigno:.3f}")
# Out:
# === Predicciones para muestras nuevas ===
# Características de las muestras:
#    mean radius  mean texture  mean perimeter  mean area
# 0         12.5          15.2            82.1      490.0
# 1         18.8          22.1           125.4     1105.0
# 2         15.2          18.5            99.8      720.0
#
# Resultados de predicción:
# Muestra | Predicción | Probabilidad Maligno | Probabilidad Benigno
# -----------------------------------------------------------------
#    1    |   Benigno  |       0.001      |       0.999
#    2    |   Maligno  |       1.000      |       0.000
#    3    |   Maligno  |       0.576      |       0.424

# %% [markdown]
# ## Guardamos el modelo usando Mlflow

# %%
import mlflow
from mlflow.sklearn import log_model
